# %% [markdown]
# # 28 th October Coding Assignment

# %%
age=25
print("the age is",age)
# Out:
# the age is 25

# %%
number=20
print(number - 1)
# Out:
# 19

# %%
First_name="Code"
Last_name="Chef"
print(First_name,Last_name)
# Out:
# Code Chef

# %%
a=23
b=20
sum=a+b
print("Sum of a and b is",sum)
# Out:
# Sum of a and b is 43

# %%
length=45
width=76
area=length*width
print("Area of rectangle is",area)
# Out:
# Area of rectangle is 3420

# %%
radius=8.9
pi=3.14
area=pi*radius*radius
print("Area of Circle is",area)
# Out:
# Area of Circle is 248.71940000000004

# %%
a="learning"
b="is fun"
print(a+" "+b+"!")
# Out:
# learning is fun!
